# %% [markdown]
# <a href="https://colab.research.google.com/github/Juuuuls/CPE311/blob/main/Seatwork_6_1_QUIBRA_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Seatwork 6.1 Exploratory Data Analysis on Your Own Dataset**
#
# CPE311 Computational Thinking with Python
#
# **Name:** Quibral, Juliann Vincent B.
#
# **Section:** CPE22S3
#
# **Performed on:** 03/11/2024
#
# **Submitted on:** 03/11/2024
#
# **Submitted to:** Engr. Roman M. Richard

# %%
file_path = "/content/delivery.csv"

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
# @title Cost_of_the_Product

from matplotlib import pyplot as plt
data['Cost_of_the_Product'].plot(kind='hist', bins=20, title='Cost_of_the_Product')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **1.Data set column names**

# %%
column_names = data.columns
print("Column Names:", column_names)
# Out:
# Column Names: Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %% [markdown]
# **2. Data set data types**

# %%
data_types = data.dtypes
print("\nData Types:\n", data_types)
# Out:
# Data Types:
#  ID                      int64
# Warehouse_block        object
# Mode_of_Shipment       object
# Customer_care_calls     int64
# Customer_rating         int64
# Cost_of_the_Product     int64
# Prior_purchases         int64
# Product_importance     object
# Gender                 object
# Discount_offered        int64
# Weight_in_gms           int64
# Reached.on.Time_Y.N     int64
# dtype: object

# %% [markdown]
# **3. Total number of records**

# %%
total_records = len(data)
print("\nTotal Number of Records:", total_records)
# Out:
# Total Number of Records: 10999

# %% [markdown]
# **4. Display the first**

# %%
print("\n\nFirst 10 Records:")
print(data.head(10))
# Out:
# First 10 Records:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %% [markdown]
# **5. Display the last 20 of the record**

# %%
print("\n\nLast 10 Records:")
print(data.tail(10))
# Out:
# Last 10 Records:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# ...

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# ...

# %%
# @title Product_importance

from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('Product_importance').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **6. Chnage the Product_importance column to Priority**

# %%
data.rename(columns={'Product_importance': 'Priority'}, inplace=True)

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases Priority Gender  \
# 0                    2                  177                3      low      F
# ...

# %%
# @title Priority

from matplotlib import pyplot as plt
import seaborn as sns
data.groupby('Priority').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **7. Create a new column Classification**

# %%
data['Delivered.Late_Y.N'] = np.where(data['Reached.on.Time_Y.N'] == 0, 'Late', 'On Time')

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases Priority Gender  \
# 0                    2                  177                3      low      F
# ...

# %%
# @title Gender vs Delivered.Late_Y.N

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Delivered.Late_Y.N'].value_counts()
    for x_label, grp in data.groupby('Gender')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Gender')
_ = plt.ylabel('Delivered.Late_Y.N')

# %% [markdown]
# **8. Create a new dataframe "lateDelivery"**

# %%
late_delivery = data[data['Reached.on.Time_Y.N'] == 0]

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases Priority Gender  \
# 0                    2                  177                3      low      F
# ...

# %% [markdown]
# **9. Create a new dataframe "good_rating"**

# %%
good_rating = data[data['Customer_rating'] <= 3]

# %% [markdown]
# **10.Create a new dataframe "bad_rating"**

# %%
bad_rating = data[data['Customer_rating'] > 3]

# %% [markdown]
# **12. Use numpy to get the average cost and discount.**

# %%
average_cost = np.mean(data['Cost_of_the_Product'])
average_discount = np.mean(data['Discount_offered'])
print("\nAverage Cost:", average_cost)
print("Average Discount:", average_discount)
# Out:
# Average Cost: 210.19683607600692
# Average Discount: 13.37321574688608

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases Priority Gender  \
# 0                    2                  177                3      low      F
# ...

# %%
# @title Cost_of_the_Product

from matplotlib import pyplot as plt
data['Cost_of_the_Product'].plot(kind='hist', bins=20, title='Cost_of_the_Product')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Customer_rating vs Cost_of_the_Product

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Customer_rating', y='Cost_of_the_Product', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **13. Use numpy to get the median cost and discount.**

# %%
median_cost = np.median(data['Cost_of_the_Product'])
median_discount = np.median(data['Discount_offered'])
print("\nMedian Cost:", median_cost)
print("Median Discount:", median_discount)
# Out:
# Median Cost: 214.0
# Median Discount: 7.0

# %%
data
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases Priority Gender  \
# 0                    2                  177                3      low      F
# ...

# %% [markdown]
# **14. Use numpy to get the middle cost and discount.**

# %%
median_cost = np.median(np.sort(data['Cost_of_the_Product']))
median_discount = np.median(np.sort(data['Discount_offered']))
print("\nMiddle median:", median_cost)
print("Middle discount:", median_discount)
# Out:
# Middle median: 214.0
# Middle discount: 7.0

# %% [markdown]
# **15. Use numpy to get the standard deviation of the discount_offered**

# %%
std_Discounts = np.std(data['Discount_offered'])
print("\nStandard Deviation of Discouns:", std_Discounts)
# Out:
# Standard Deviation of Discouns: 16.204790382056665

# %% [markdown]
# **Conclusion**

# %% [markdown]
# Upon doing the Seatwork and Hands on Activity data analysis tasks are the primary use case for Pandas. Working with numerical numbers is the primary usage of NumPy since it simplifies the application of mathematical functions. The pandas library functions effectively with both alphabetic and numeric data simultaneously. When doing logical and mathematical computations on arrays and matrices, NumPy is a great tool. Compared to Python lists, this utility completes these tasks substantially more quickly and effectively. The primary benefit of Numpy is its reduced memory and storage space use. In addition, Data alignment and integrated handling of missing data, data set merging and joining, data set reshaping and pivoting, label-based slicing, hierarchical axis indexing to work with high-dimensional data in a lower-dimensional data structure, and other advantages are also obtained from the Pandas library. With these tools data handling is made easier and more convenient.
